# %%
import pandas as pd
import numpy as np
import seaborn as sns
import calendar
import matplotlib.pyplot as plt
import random

# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
raw_df = pd.read_csv("Happiness 2019.csv")
raw_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#null value analysis
ax = plt.axes()
ax.set_facecolor("white")
raw_df.isna().sum().plot(kind='bar', color='red', figsize=(15, 7), fontsize=12)
plt.xlabel('Columns', labelpad=7, loc='center', fontsize=15)
plt.ylabel('Missing count', labelpad=7, fontsize=15)
plt.title('Missing information analysis', pad=15, fontsize=25)
plt.grid(False)

# %%
raw_df.isna().sum()
#found that there is no any null value
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
raw_df.iloc[random.randint(0,raw_df.shape[0])]
# Out:
# Overall rank                        68
# Country or region               Russia
# Score                            5.648
# GDP per capita                   1.183
# Social support                   1.452
# Healthy life expectancy          0.726
# Freedom to make life choices     0.334
# Generosity                       0.082
# Perceptions of corruption        0.031
# Name: 67, dtype: object

# %%
raw_df.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
country_or_region = raw_df.groupby('Country or region').aggregate({'Country or region':'count'})
country_or_region.rename(columns={'Country or region':'Country or region count'},inplace=True)
country_or_region.sort_values('Country or region count',ascending=False)
#here found that the data has no repeatative country
# Out:
#                          Country or region count
# Country or region
# Afghanistan                                    1
# Palestinian Territories                        1
# Nicaragua                                      1
# Niger                                          1
# Nigeria                                        1
# ...                                          ...
# Guinea                                         1
# Haiti                                          1
# Honduras                                       1
# Hong Kong                                      1
# Zimbabwe                                       1
#
# [156 rows x 1 columns]

# %%
df = raw_df.copy(deep=True)
df.set_index('Country or region',inplace=True)
df
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %%
raw_df[raw_df['Country or region']=='India']
#getting the data of india
# Out:
#      Overall rank Country or region  Score  GDP per capita  Social support  \
# 139           140             India  4.015           0.755           0.765
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 139                    0.588                         0.498         0.2
#
#      Perceptions of corruption
# 139                      0.085

# %%
df['Positivity Score'] = df[df.columns[1:-1]].sum(axis=1)
df.sort_values('Positivity Score',ascending=False)
# so here we can conclude that the best country to live is norway
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Switzerland                          6  7.480           1.452           1.526
# ...                                ...    ...             ...             ...
# Syria                              149  3.462           0.619           0.378
# Burundi                            145  3.775           0.046           0.447
# Afghanistan                        154  3.203           0.350           0.517
# South Sudan                        156  2.853           0.306           0.575
# Central African Republic           155  3.083           0.026           0.000
#
# ...

# %%
df['Best country score'] = df['Positivity Score']-df['Perceptions of corruption']

# %%
#shifting thenegative column to the end
column = df.pop('Perceptions of corruption')
df.insert(9,'Perceptions of corruption', column)
df
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %%
for x in df.columns:
    df[x].sort_values().plot(kind='barh', figsize=(10, 30), color='#ffcc00')
    plt.grid(False)
    plt.title(f"2019 {x}", fontsize=20,pad=15)
    plt.xlabel(x, fontsize=15)
    plt.ylabel('Country', fontsize=15)
    plt.show();

# %%
df[df.columns[1:-1]].reset_index().sort_values('Best country score').plot(x='Country or region', kind='barh', stacked=True, figsize=(15, 30));
plt.grid(False)
plt.title(f"2019 Happiness", fontsize=20,pad=15)
plt.xlabel('Overall data', fontsize=15)
plt.ylabel('Country', fontsize=15)
plt.show();

# %%
df.sort_values('Best country score',ascending=False).head()
#this countries are best to live according to the Best country score
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Iceland                       4  7.494           1.380           1.624
# Norway                        3  7.554           1.488           1.582
# Finland                       1  7.769           1.340           1.587
# Switzerland                   6  7.480           1.452           1.526
# Denmark                       2  7.600           1.383           1.573
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Iceland                              1.026                         0.591
# Norway                               1.028                         0.603
# Finland                              0.986                         0.596
# Switzerland                          1.052                         0.572
# Denmark                              0.996                         0.592
#
# ...

# %%
df.sort_values('Perceptions of corruption').head()
#this countries have the least corruption
# Out:
#                         Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Moldova                           71  5.529           0.685           1.328
# Bulgaria                          97  5.011           1.092           1.513
# Romania                           48  6.070           1.162           1.232
# Kosovo                            46  6.100           0.882           1.232
# Bosnia and Herzegovina            78  5.386           0.945           1.212
#
#                         Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Moldova                                   0.739                         0.245
# Bulgaria                                  0.815                         0.311
# Romania                                   0.825                         0.462
# Kosovo                                    0.758                         0.489
# Bosnia and Herzegovina                    0.845                         0.212
#
# ...
